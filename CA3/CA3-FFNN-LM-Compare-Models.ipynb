# %%
import matplotlib.pyplot as plt
import numpy as np

train_perp1 = np.loadtxt('perp_train_lm_5w_35n_lr_02_glove.csv', delimiter=',')
train_perp2 = np.loadtxt('perp_train_lm_4w_35n_lr_02_glove.csv', delimiter=',')
train_perp3 = np.loadtxt('perp_train_lm_3w_35n_lr_02_glove.csv', delimiter=',')

x = np.array(range(len(train_perp1)))

# plot the data
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.plot(x, train_perp1, color='tab:blue', label='5-gram')
ax.plot(x, train_perp2, color='tab:orange', label='4-gram')
ax.plot(x, train_perp3, color='tab:green', label='3-gram')

ax.set_title("Evaluate Perplexity based ?-grams")
ax.set_xlabel('Epoch')
ax.set_ylabel('Perplexity')
plt.legend(loc="upper right")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

train_perp1 = np.loadtxt('perp_test_lm_5w_35n_lr_02_glove.csv', delimiter=',')
train_perp2 = np.loadtxt('perp_test_lm_4w_35n_lr_02_glove.csv', delimiter=',')
train_perp3 = np.loadtxt('perp_test_lm_3w_35n_lr_02_glove.csv', delimiter=',')

x = np.array(range(len(train_perp1)))

# plot the data
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.plot(x, train_perp1, color='tab:blue', label='5-gram')
ax.plot(x, train_perp2, color='tab:orange', label='4-gram')
ax.plot(x, train_perp3, color='tab:green', label='3-gram')

ax.set_title("Evaluate Val-Perplexity based ?-grams")
ax.set_xlabel('Epoch')
ax.set_ylabel('Perplexity')
plt.legend(loc="upper right")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

train_perp1 = np.loadtxt('perp_train_lm_5w_35n_lr_01_glove.csv', delimiter=',')
train_perp2 = np.loadtxt('perp_train_lm_5w_35n_lr_02_glove.csv', delimiter=',')
train_perp3 = np.loadtxt('perp_train_lm_5w_35n_lr_03_glove.csv', delimiter=',')
train_perp4 = np.loadtxt('perp_train_lm_5w_35n_lr_1_glove.csv', delimiter=',')
x = np.array(range(len(train_perp1)))

# plot the data
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.plot(x, train_perp1, color='tab:blue', label='0.01 learning rate')
ax.plot(x, train_perp2, color='tab:orange', label='0.02 learning rate')
ax.plot(x, train_perp3, color='tab:green', label='0.03 learning rate')
ax.plot(x, train_perp4, color='tab:purple', label='0.1 learning rate')

ax.set_title("Evaluate Perplexity based ? LR")
ax.set_xlabel('Epoch')
ax.set_ylabel('Perplexity')
plt.legend(loc="upper right")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

train_perp1 = np.loadtxt('perp_test_lm_5w_35n_lr_01_glove.csv', delimiter=',')
train_perp2 = np.loadtxt('perp_test_lm_5w_35n_lr_02_glove.csv', delimiter=',')
train_perp3 = np.loadtxt('perp_test_lm_5w_35n_lr_03_glove.csv', delimiter=',')
train_perp4 = np.loadtxt('perp_test_lm_5w_35n_lr_1_glove.csv', delimiter=',')
x = np.array(range(len(train_perp1)))

# plot the data
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.plot(x, train_perp1, color='tab:blue', label='0.01 learning rate')
ax.plot(x, train_perp2, color='tab:orange', label='0.02 learning rate')
ax.plot(x, train_perp3, color='tab:green', label='0.03 learning rate')
ax.plot(x, train_perp4, color='tab:purple', label='0.1 learning rate')

ax.set_title("Evaluate Val-Perplexity based ? LR")
ax.set_xlabel('Epoch')
ax.set_ylabel('Perplexity')
plt.legend(loc="upper right")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

train_perp1 = np.loadtxt('perp_train_lm_5w_35n_lr_02_glove.csv', delimiter=',')
train_perp2 = np.loadtxt('perp_train_lm_5w_50n_lr_02_glove.csv', delimiter=',')
train_perp3 = np.loadtxt('perp_train_lm_5w_100n_lr_02_glove.csv', delimiter=',')
train_perp4 = np.loadtxt('perp_train_lm_5w_150n_lr_02_glove.csv', delimiter=',')
x = np.array(range(len(train_perp1)))

# plot the data
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.plot(x, train_perp1, color='tab:blue', label='35 hidden_size')
ax.plot(x, train_perp2, color='tab:orange', label='50 hidden_size')
ax.plot(x, train_perp3, color='tab:green', label='100 hidden_size')
ax.plot(x, train_perp4, color='tab:purple', label='150 hidden_size')

ax.set_title("Evaluate Perplexity based ? hidden_size")
ax.set_xlabel('Epoch')
ax.set_ylabel('Perplexity')
plt.legend(loc="upper right")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

train_perp1 = np.loadtxt('perp_test_lm_5w_35n_lr_02_glove.csv', delimiter=',')
train_perp2 = np.loadtxt('perp_test_lm_5w_50n_lr_02_glove.csv', delimiter=',')
train_perp3 = np.loadtxt('perp_test_lm_5w_100n_lr_02_glove.csv', delimiter=',')
train_perp4 = np.loadtxt('perp_test_lm_5w_150n_lr_02_glove.csv', delimiter=',')
x = np.array(range(len(train_perp1)))

# plot the data
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.plot(x, train_perp1, color='tab:blue', label='35 hidden_size')
ax.plot(x, train_perp2, color='tab:orange', label='50 hidden_size')
ax.plot(x, train_perp3, color='tab:green', label='100 hidden_size')
ax.plot(x, train_perp4, color='tab:purple', label='150 hidden_size')

ax.set_title("Evaluate Val_Perplexity based ? hidden_size")
ax.set_xlabel('Epoch')
ax.set_ylabel('Perplexity')
plt.legend(loc="upper right")
plt.show()
